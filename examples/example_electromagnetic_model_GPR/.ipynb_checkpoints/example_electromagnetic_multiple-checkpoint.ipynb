# %%
import sys, importlib
sys.path.insert(0, r'F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator')

# %%
import copy
import pandas as pd
import numpy as np
import geomodgen2d as gm

# %%
# Step 1: Unit Configuration

# %%
units_config = gm.units_config.Units() #Using default units config of "m"

# %%
# Step 2: Define Feature and Properties

# %%
from scipy.stats import multivariate_normal, norm
class CorrelatedUniformBivariateXLogY(gm.random_generators.RandomGeneratorAbstract):
    def __init__(self, u_low_x, u_high_x, u_low_logy, u_high_logy, r_x_logy, rng=None):
        """
        Initializes a correlated uniform random generator using a Gaussian copula.

        X  ~ Uniform(u_low_x, u_high_x)
        log10(Y) ~ Uniform(log10(u_low_logy), log10(u_high_logy))
        Corr(X, log10(Y)) = r_x_logy
        
        Parameters
            u_low_x, u_high_x : float :  Range for Variable1.
            u_low_logy, u_high_logy : float : Range for Variable2.
            r : float : Correlation coefficient between Variable 1 and Variable 2.
            r_comp_axis: string : Axes scale for correlation computation.
                First element must be in {"x", "log10x"}, second in {"y", "log10y"}.
                That is Options: ['x', 'y'], ['log10x', 'log10y'], ['log10x', 'y'], ['x', 'log10y']]
        """
        self.u_low_x = u_low_x
        self.u_high_x = u_high_x
        self.u_low_logy = u_low_logy
        self.u_high_logy = u_high_logy
        
        # --- means checks ---
        if u_low_x > u_high_x:
            raise ValueError("u_low_x must be < u_high_x")
        if u_low_logy <= 0 or u_high_logy <= 0:
            raise ValueError("Log-uniform variable must be strictly positive.")
        if u_low_logy > u_high_logy:
            raise ValueError("u_low_logy must be < u_high_logy")

        # --- correlation checks ---
        if not isinstance(r_x_logy, (int, float)):
            raise TypeError("Correlation coefficient r must be a float or int.")
        if not -1 <= r_x_logy <= 1:
            raise ValueError(f"Correlation coefficient r must be between -1 and 1, got {r_x_logy}")
            
        self.r_x_logy = r_x_logy

    def generate(self, size=1):
        if isinstance(size, int):
            n = size
            out_shape = (size, 2)
        else:
            raise TypeError("size must be int")
            
        cov = [[1, self.r_x_logy], [self.r_x_logy, 1]]
        z = multivariate_normal.rvs(mean=[0, 0], cov=cov, size=size)
        u = norm.cdf(z)
        u = u.reshape(-1, 2)
        
        x = self.u_low_x + (self.u_high_x - self.u_low_x) * u[:, 0]
        logy = np.log10(self.u_low_logy) + (np.log10(self.u_high_logy) - np.log10(self.u_low_logy)) * u[:, 1]
        y = 10 ** logy
       
        samples = np.column_stack((x, y))
        return samples.reshape(out_shape)

# %%
rng = np.random.default_rng(seed=42)
layer0_flag = False

soil_materials_distribution = gm.random_generators.Constant(val = 'sand', rng=rng)

feature_config_instance =  gm.features_config.FeaturesConfig()
feature_config_instance.add_feature('def', soil_materials_distribution, 'soil')

main_properties_config_instance =  gm.main_properties.MainPropertiesConfig(feature_config_instance, layer0_flag=layer0_flag)

main_properties_info = {'ec': {'desc':'electric conductivity'},
                       'dc': {'desc':"dielectric constant"},
                       }

# dc property added:
main_property_name = 'ec'
main_props_vals = main_properties_info[main_property_name]

#Define MainProperty instance
main_property_instance = gm.main_property_each.MainProperty(main_property_name, feature_config_instance, layer0_flag=False, description=main_props_vals['desc'])

# Define wet and dry properties
corr_coeff = 0.78
wet_mean_distribution = CorrelatedUniformBivariateXLogY(20, 30, 0.1, 1, corr_coeff, rng)
dry_mean_distribution = CorrelatedUniformBivariateXLogY(3, 5, 0.01, 0.01, corr_coeff, rng)
cov_distribution = gm.random_generators.Constant(0.05, rng)
cov_type = 'cov'
wet_prop = gm.main_property_each.PropertyDistribution(main_property_name,  wet_mean_distribution, cov_distribution, stdev_type=cov_type)
dry_prop = gm.main_property_each.PropertyDistribution(main_property_name,  dry_mean_distribution, cov_distribution, stdev_type=cov_type)

# Add property instance to MainProperty 
main_property_instance.add_material_property_of_feature(feature_id='def', material_name='sand', property_distribution_instance=wet_prop, property_distribution_instance_if_dry=dry_prop)

# Add MainProperty to MainPropertiesConfig instance
main_properties_config_instance.add_main_property(main_property_instance)


# DC property definition
main_property_name = 'dc'
main_props_vals = main_properties_info[main_property_name]
main_property_instance = gm.main_property_each.MainProperty(main_property_name, feature_config_instance, layer0_flag=layer0_flag, description=main_props_vals['desc'])
wet_mean_distribution = gm.random_generators.Constant(-999, rng)  # Filler to be replaced later
dry_mean_distribution = gm.random_generators.Constant(-999, rng)  # Filler to be replaced later
cov_distribution = gm.random_generators.Constant(0.05, rng)
cov_type = 'cov'
wet_prop = gm.main_property_each.PropertyDistribution(main_property_name,  wet_mean_distribution, cov_distribution, stdev_type=cov_type)
dry_prop = gm.main_property_each.PropertyDistribution(main_property_name,  dry_mean_distribution, cov_distribution, stdev_type=cov_type)
main_property_instance.add_material_property_of_feature(feature_id='def', material_name='sand', property_distribution_instance=wet_prop, property_distribution_instance_if_dry=dry_prop)
main_properties_config_instance.add_main_property(main_property_instance)

# %%
main_properties_config_instance.print()
# Out:
# Main_Properties: ['ec', 'dc']
# feature_ids: ['def']
# ---------------------------
# Property Name: ec
# Description: electric conductivity
# All Feature IDs: ['def']
# Properties:
# {'def': {'sand': {'wet': <geomodgen2d.main_property_each.PropertyDistribution object at 0x000001FBB72A4FE0>,
#                   'dry': <geomodgen2d.main_property_each.PropertyDistribution object at 0x000001FBB72EA390>}}}
# ---------------------------
# Property Name: dc
# Description: dielectric constant
# All Feature IDs: ['def']
# Properties:
# {'def': {'sand': {'wet': <geomodgen2d.main_property_each.PropertyDistribution object at 0x000001FBB72EA430>,
#                   'dry': <geomodgen2d.main_property_each.PropertyDistribution object at 0x000001FBB72EA660>}}}

# %%
main_properties_config_instance.main_properties['ec'].generate_sample_dict('def', 'sand')

## Here readjustment of 'means' are needed as bivariate is not in-built accompanied in geomodgen2d
# Out:
# {'wet': {'mean': array([[24.01690036,  0.18625961]]),
#   'mean_bm': 0,
#   'stdev/cov': 0.05,
#   'stdev_type': 'cov'},
#  'dry': {'mean': array([[3.70246619, 0.01      ]]),
#   'mean_bm': 0,
#   'stdev/cov': 0.05,
#   'stdev_type': 'cov'}}

# %%
# Step 2: Model Settings

# %%
x_span = 5
z_span = 3

n_layers = 4
gwt_depth = 10

del_xz_spatial = 0.05    #del_y value for boundary generation and spatial 
del_xz_final = 0.05  #refining del_z for utilities generation
remesh_interp_method = 'linear'
spatial_theta_x = 100
spatial_theta_z = 0.5

interface_sett= {
    'generate_surface':False,
    'rough_interface_creator_instance':gm.rough_interface_creator2d.UniformInterfaceGen(1, rng=rng),
    'rough_interface_generator_scale': [0,1.3,1.2,1], # If n_soil_layers>len(this list) uses last value for those layers.
    'interfaces_depths_generation':[0, 0.4, 1, 2.3], 
    'interfaces_depth_reference_point_x':2.5,
    'filter_settings': {
                 'filter_window_length':21, #21 #must be odd
                 'filter_polyorder':7,
                        },
    'processing_settings': {
                'simulate_erosion': True,
            }
    }

# %%
# Step 2.1 Domain Creation
domain_spatial = gm.discretized_domain2d.DiscretizedDomain2D(x_span, z_span, del_xz_spatial, del_xz_spatial, units_config)
domain_final   = gm.discretized_domain2d.DiscretizedDomain2D(x_span, z_span, del_xz_final, del_xz_final, units_config)

# %%
all_profiles = {}


for i in range(10):
    soil_interface = gm.discretized_interfaces2d_from_dict.DiscretizedInterfaces2DFromDict(domain_spatial, n_layers, interface_sett, remesh_interp_method=remesh_interp_method, rng=rng)
    soil_interface.plot()
    
    global_soil_interface_config = gm.lithological_domain2d.GlobalSoilInterfaceConfig
    global_soil_interface_config.reset()
    global_soil_interface_config.set_soil_interface(soil_interface)
    
    name = 'asdf'
    lit = gm.lithological_domain2d.LithologicalDomain2D(domain_spatial, gwt_depth, 'soil_lit')
    lit.plot(discrete_point_size = 10, plot_interfaces=True)
    lit.lm_type
    
    lit_collection = gm.lithological_domain2d_collection.LithologicalDomain2DCollection(main_properties_config_instance.get_feature_ids(), interface_set_name="soil") 
    lit_collection.add_lithological_domain_from_soil_interface_config(lit)
    lit_collection.lock()
    
    main_properties_config_instance.unlock()
    main_properties_config_instance.lock_and_generate_sample_properties(lit_collection)
    sample_properties = main_properties_config_instance.sampled_properties
    
    for lit_id in sample_properties['ec'].keys():
        for case in ['dry', 'wet']:
            dc_ec = sample_properties['ec'][lit_id][case]['mean']
            dc, ec = float(dc_ec[0][0]), float(dc_ec[0][1])
            sample_properties['dc'][lit_id][case]['mean'] = dc
            sample_properties['ec'][lit_id][case]['mean'] = ec
    main_properties_config_instance._sampled_properties = sample_properties
    
    #Spatial Simulator
    spatial_sim = gm.spatial_simulator2d.CovarianceDecompositionSimulator(spatial_theta_x, spatial_theta_z, rng)
    # Collection
    
    gen_profiles = gm.generated_model2d_collection.GeneratedProfileCollection2D(main_properties_config_instance, lit_collection, spatial_sim)
    gen_profiles.simulate_property_profile('dc')        
    gen_profiles.simulate_property_profile('ec')

    all_profiles[i] = gen_profiles
# Out:
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.0431432819697184 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.2193104433717545 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.438955424247076 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.0778695395949394 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.007056689646190871 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.014903026365267117 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.04787083239716976 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.005859313948508859 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.4703453684309837 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.2255171759371146 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.0315264248332985 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.0342286870044697 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.028332857157948463 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.011852604270249326 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.013990845280447348 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.005462187339599824 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.3672203190610461 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.123504710821545 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.1364825042784699 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.1114543498986278 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.03356229763399195 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.008290605563077532 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.029811206913063104 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.015008533497463145 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.023537379823971 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.4096122577686914 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.3682226251069958 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.199080919250664 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.006787413380115879 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.03693653722278089 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.00708240993505111 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.014013450808196399 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.4751750864742545 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.4850875653039122 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.1234875793892496 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.2428338239068006 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.035726699470148685 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.04507714373316332 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.012442427907401628 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.010994844300033318 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.0999768281894045 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.2002903177150424 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.3201189050403626 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.2785720590081133 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.0153332115067546 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.017453512650261883 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.009876310502889745 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.008526635603952426 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.0877746628615357 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.241911720053016 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.4721948648429635 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.1124833311675824 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.013264941735646994 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.022904814387533907 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.026297327134212064 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.007705352172809925 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.0013827687037917 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.114484791884755 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.2115083690328183 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.4234258690983717 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.005517137724137356 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.006103628840202335 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.016397927344149008 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.01515395281821812 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.2734715331708963 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.022646529493709 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.3999548701801103 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.0306655429547165 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.014871848916757061 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.00571584389202829 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.042038814864906064 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.0065199787222907845 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\discretized_interfaces2d.py:505: UserWarning: Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.
#   warnings.warn("Overlapping interfaces found after remesh; Applied default erosion processing at the edges to correct them. This should not affect most models.")
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 1
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=1.1574595210588743 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=1.040814833818192 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=1.1369038662122242 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=1.1314057476189716 but all simulated values are zero.
#   warnings.warn(
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 2
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 3
# Z-vals: spatial-with-sigma
# Simulating z-vals for Layer ID: 4
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 2 (wet): sigma=0.007959410006674422 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 3 (wet): sigma=0.005878051971571927 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 1 (wet): sigma=0.0057400286061175775 but all simulated values are zero.
#   warnings.warn(
# F:\V_Tech Semesters\MS Thesis\Jupyter_MS\2D_Model_Generator\geomodgen2d\spatial_simulator2d.py:294: UserWarning: Layer 4 (wet): sigma=0.008589873161856795 but all simulated values are zero.
#   warnings.warn(

# %%
# Figure 7
import matplotlib
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed=5)
matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.serif']= ['Times New Roman'] + plt.rcParams['font.serif']
matplotlib.rcParams['font.size'] = 11

fig, axs = plt.subplots(1, 3, figsize=(7, 10/4), sharex=True, sharey=True)

legendkwargs_dict = {
    'shrink':0.3,
    'aspect':8,
    'pad':0.1
}


ax = axs[0]
gen_profiles = all_profiles[0]
gen_profiles.merged_generated_model2d.plot_profile('dc', ax=ax, legend_label = 'd. c.', legendkwargs_dict=legendkwargs_dict)
ax.set(ylabel="Z (m)", xlabel=None, title=None)

ax = axs[1]
gen_profiles = all_profiles[1]
gen_profiles.merged_generated_model2d.plot_profile('dc', ax=ax, legend_label = 'd. c.', legendkwargs_dict=legendkwargs_dict)
ax.set(ylabel=None, xlabel=None, title=None)

ax = axs[2]
gen_profiles = all_profiles[2]
gen_profiles.merged_generated_model2d.plot_profile('dc', ax=ax, legend_label = 'd. c.', legendkwargs_dict=legendkwargs_dict)
ax.set(ylabel=None, xlabel=None, title=None)

# ax = axs[1]
# gen_profiles.merged_generated_model2d.plot_profile('miu', ax=ax)

fig.tight_layout(rect=[0.05, 0.05, 1, 1])  # Leave space for shared labels
fig.savefig(r"F:\V_Tech Semesters\MS Thesis\Jupyter_MS\Papers_figures\Geomodgen2d_paper\Figure10_raw.svg", format="svg", bbox_inches='tight', metadata={'Creator':'Matplotlib'})

# ax.set(yscale='log', ylabel=None, xlabel=None, ylim=[0,1], title=None)

# %%
def plot_lit_lines(ax, delx = 1):
    z = [0, 0.4, 1, 2.3]
    x = 2.5

    x1 = x - delx/2
    x2 = x + delx/2

    for z_val in z:
        ax.plot([x1,x2], [z_val, z_val], c = 'k', alpha = 0.5)

    ax.plot([x,x], [0,3], c='k', linewidth=0.2)
    return ax

fig, axs = plt.subplots(1, 3, figsize=(7, 10/4), sharex=True, sharey=True)

legendkwargs_dict = {
    'shrink':0.3,
    'aspect':8,
    'pad':0.1
}


ax = axs[0]
gen_profiles = all_profiles[0]
gen_profiles.merged_generated_model2d.plot_lit_domain(ax=ax, legend=False)
ax = plot_lit_lines(ax, 1)
ax.set(ylabel="Z (m)", xlabel=None, title=None)

ax = axs[1]
gen_profiles = all_profiles[1]
gen_profiles.merged_generated_model2d.plot_lit_domain(ax=ax, legend=False)
ax = plot_lit_lines(ax, 1)
ax.set(ylabel=None, xlabel=None, title=None)

ax = axs[2]
gen_profiles = all_profiles[2]
gen_profiles.merged_generated_model2d.plot_lit_domain(ax=ax, legend=False)
ax = plot_lit_lines(ax, 1)
ax.set(ylabel=None, xlabel=None, title=None)

# ax = axs[1]
# gen_profiles.merged_generated_model2d.plot_profile('miu', ax=ax)

fig.tight_layout(rect=[0.05, 0.05, 1, 1])  # Leave space for shared labels
fig.savefig(r"F:\V_Tech Semesters\MS Thesis\Jupyter_MS\Papers_figures\Geomodgen2d_paper\Figure10_raw.svg", format="svg", bbox_inches='tight', metadata={'Creator':'Matplotlib'})

# ax.set(yscale='log', ylabel=None, xlabel=None, ylim=[0,1], title=None)

# %%
gen_profiles.merged_generated_model2d.lit_domain.lithological_matrix.shape
# Out:
# (100, 60)
